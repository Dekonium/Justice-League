# %%
#varblies and definng the URFL 
import csv
import json
import pandas as pd
import requests
import re 
import numpy as np
import matplotlib.pyplot as plt
import flask
from pandas.io.json import json_normalize
import urllib
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets
#importing libraries

# %%
#checking Police Forces that exist
url_forces = "https://data.police.uk/api/west-midlands/neighbourhoods"
response_forces = requests.get(url_forces).json()
response_forces
# Out:
# [{'id': 'BE001', 'name': 'Erdington'},
#  {'id': 'BE002', 'name': 'Kingstanding'},
#  {'id': 'BE003', 'name': 'Stockland Green'},
#  {'id': 'BE004', 'name': 'Tyburn'},
#  {'id': 'BE005', 'name': 'Hall Green'},
#  {'id': 'BE006', 'name': 'Moseley and Kings Heath'},
#  {'id': 'BE007', 'name': 'Sparkbrook'},
#  {'id': 'BE008', 'name': 'Springfield'},
#  {'id': 'BE009', 'name': 'Bordesley Green'},
#  {'id': 'BE010', 'name': 'Hodge Hill'},
#  {'id': 'BE011', 'name': 'Shard End'},
#  {'id': 'BE012', 'name': 'Washwood Heath'},
#  {'id': 'BE013', 'name': 'Sutton Four Oaks'},
#  {'id': 'BE014', 'name': 'Sutton New Hall'},
#  {'id': 'BE015', 'name': 'Sutton Trinity'},
#  {'id': 'BE016', 'name': 'Sutton Vesey'},
#  {'id': 'BE017', 'name': 'Acocks Green'},
#  {'id': 'BE018', 'name': 'Sheldon'},
#  {'id': 'BE019', 'name': 'South Yardley'},
#  {'id': 'BE020', 'name': 'Stechford and Yardley North'},
#  {'id': 'BW001', 'name': 'City Centre'},
#  {'id': 'BW002', 'name': 'Bartley Green'},
#  {'id': 'BW003', 'name': 'Edgbaston'},
#  {'id': 'BW004', 'name': 'Harborne'},
#  {'id': 'BW005', 'name': 'Quinton'},
#  {'id': 'BW006', 'name': 'Aston'},
#  {'id': 'BW007', 'name': 'Nechells'},
#  {'id': 'BW008', 'name': 'Small Heath and Highgate'},
#  {'id': 'BW010', 'name': 'Kings Norton'},
#  {'id': 'BW011', 'name': 'Longbridge'},
#  {'id': 'BW012', 'name': 'Northfield'},
#  {'id': 'BW013', 'name': 'Weoley'},
#  {'id': 'BW014', 'name': 'Handsworth Wood'},
#  {'id': 'BW015', 'name': 'Lozells and East Handsworth'},
#  {'id': 'BW016', 'name': 'Oscott'},
#  {'id': 'BW017', 'name': 'Perry Barr'},
#  {'id': 'BW018', 'name': 'Billesley'},
#  {'id': 'BW019', 'name': 'Bournville'},
#  {'id': 'BW020', 'name': 'Brandwood'},
#  {'id': 'BW021', 'name': 'Selly Oak'},
#  {'id': 'BW022', 'name': 'Jewellery Quarter'},
#  {'id': 'BW023', 'name': 'Ladywood'},
#  {'id': 'BW024', 'name': 'Soho Road'},
#  {'id': 'BW025', 'name': 'Winson Green'},
#  {'id': 'CV002', 'name': 'Foleshill'},
#  {'id': 'CV005', 'name': 'Stoke and Wyken'},
#  {'id': 'CV010', 'name': "St Michael's"},
#  {'id': 'CV011', 'name': 'Henley and Longford'},
#  {'id': 'CV012', 'name': 'Binley, Willenhall, Cheylesmore and Earlsdon'},
#  {'id': 'CV013', 'name': 'Holbrook, Radford, Sherbourne and Bablake'},
#  {'id': 'CV014', 'name': 'Woodlands, Wainbody, Westwood and Whoberley'},
#  {'id': 'DY001', 'name': 'Dudley Central'},
#  {'id': 'DY002', 'name': 'Dudley North'},
#  {'id': 'DY003', 'name': 'Halesowen'},
#  {'id': 'DY004', 'name': 'Brierley Hill'},
#  {'id': 'DY005', 'name': 'Stourbridge'},
#  {'id': 'SH001', 'name': 'Chelmsley Wood'},
#  {'id': 'SH002', 'name': 'Rural'},
#  {'id': 'SH003', 'name': "Smith's Wood"},
#  {'id': 'SH004', 'name': 'LEOS'},
#  {'id': 'SH005', 'name': 'Shirley'},
#  {'id': 'SH006', 'name': 'St Alphege'},
#  {'id': 'SH098', 'name': 'Birmingham Airport'},
#  {'id': 'SH099', 'name': 'NEC'},
#  {'id': 'SW001', 'name': 'Tipton Town'},
#  {'id': 'SW002', 'name': 'Wednesbury Town'},
#  {'id': 'SW003', 'name': 'West Bromwich Town'},
#  {'id': 'SW004', 'name': 'Oldbury Town'},
#  {'id': 'SW005', 'name': 'Rowley Town'},
#  {'id': 'SW006', 'name': 'Smethwick Town'},
#  {'id': 'WS001', 'name': 'Blakenall'},
#  {'id': 'WS002', 'name': 'Bloxwich'},
#  {'id': 'WS003', 'name': 'Delves'},
#  {'id': 'WS004', 'name': 'Pleck'},
#  {'id': 'WS005', 'name': 'Aldridge'},
#  {'id': 'WS006', 'name': 'Brownhills'},
#  {'id': 'WS007', 'name': 'Darlaston'},
#  {'id': 'WS008', 'name': 'Willenhall'},
#  {'id': 'WS009', 'name': "St Matthew's"},
#  {'id': 'WV001', 'name': 'Wolverhampton City Centre'},
#  {'id': 'WV002', 'name': 'Bilston'},
#  {'id': 'WV003', 'name': 'Ettingshall, Blakenhall and Spring Vale'},
#  {'id': 'WV004', 'name': 'Fallings Park, Bushbury, Low Hill and Oxley'},
#  {'id': 'WV005', 'name': 'Heath Town and East Park'},
#  {'id': 'WV006', 'name': "St Peter's, Park and Graiseley"},
#  {'id': 'WV007', 'name': 'Tettenhall, Penn and Merry Hill'},
#  {'id': 'WV008', 'name': 'Wednesfield North and South'}]

# %%
#checking Police Forces that exist
url_locator= "https://data.police.uk/api/west-midlands/"


id_code = ['BE001/people', 'BE002/people', 'BE003/people', 'BE004/people', 'BE005/people',
           'BE006/people', 'BE007/people','BE008/people', 'BE009/people', 'BE010/people',
           'BE011/people', 'BE012/people' ,'BE013/people', 'BE014/people', 'BE015/people', 
           'BE016/people', 'BE017/people', 'BE018/people',  'BE019/people', 'BE020/people', 
           'BW001/people', 'BW001/people','BW002/people', 'BW003//people','BW004/people', 
           'BW005/people', 'BW006/people', 'BW007/people', 'BW008/people', 'BW009/people', 
           'BW010/people', 'BW011/people', 'BW012/people','BW013/people','BW014/people', 
           'BW015/people', 'BW016/people', 'BW017/people', 'BW018/people', 'BW019/people', 
           'BW020/people', 'BW021/people', 'BW022/people', 'BW023/people',
           'BW024/people', 'BW025/people','BE011/people', 'BE012/people' ,'BE013/people', 
           'BE014/people', 'BE015/people', 'BE016/people', 'BE017/people', 'BE018/people',
           'BE019/people', 'BE020/people', 'BW001/people', 'BW001/people','BW002/people',
           'BW003/people','BW004/people', 'BW00/people5', 'BW006/people', 
             'BW007/people', 'BW008/people', 'BW009/people', 'BW010/people', 'BW011/people', 
           'BW012/people','BW013/people','BW014/people', 'BW015/people',
           'CV005/people','CV010/people','CV011/people','CV012/people','CV013/people','CV014/people',
           'DY001/people','DY002/people','DY003/people','DY004/people',
           'DY005/people','SH001/people','SH002/people','SH003/people','SH004/people','SH005/people',
           'SH006/people','SH098/people', 'SH099/people','SW001/people',
           'SW002/people','SW003/people','SW004/people','SW005/people','SW006/people',
           'WS001/people','WS002/people','WS003/people','WS004/people','WS005/people',
           'WS006/people','WS007/people','WS008/people','WS009/people',
           'WV001/people','WV002/people','WV003/people','WV004/people','WV005/people','WV006/people','WV007/people',
           'WV008/people']

url_force = [ url_locator + str(i) for i in id_code]
print (url_force)
# Out:
# ['https://data.police.uk/api/west-midlands/BE001/people', 'https://data.police.uk/api/west-midlands/BE002/people', 'https://data.police.uk/api/west-midlands/BE003/people', 'https://data.police.uk/api/west-midlands/BE004/people', 'https://data.police.uk/api/west-midlands/BE005/people', 'https://data.police.uk/api/west-midlands/BE006/people', 'https://data.police.uk/api/west-midlands/BE007/people', 'https://data.police.uk/api/west-midlands/BE008/people', 'https://data.police.uk/api/west-midlands/BE009/people', 'https://data.police.uk/api/west-midlands/BE010/people', 'https://data.police.uk/api/west-midlands/BE011/people', 'https://data.police.uk/api/west-midlands/BE012/people', 'https://data.police.uk/api/west-midlands/BE013/people', 'https://data.police.uk/api/west-midlands/BE014/people', 'https://data.police.uk/api/west-midlands/BE015/people', 'https://data.police.uk/api/west-midlands/BE016/people', 'https://data.police.uk/api/west-midlands/BE017/people', 'https://data.police.uk/api/west-midlands/BE018/people', 'https://data.police.uk/api/west-midlands/BE019/people', 'https://data.police.uk/api/west-midlands/BE020/people', 'https://data.police.uk/api/west-midlands/BW001/people', 'https://data.police.uk/api/west-midlands/BW001/people', 'https://data.police.uk/api/west-midlands/BW002/people', 'https://data.police.uk/api/west-midlands/BW003//people', 'https://data.police.uk/api/west-midlands/BW004/people', 'https://data.police.uk/api/west-midlands/BW005/people', 'https://data.police.uk/api/west-midlands/BW006/people', 'https://data.police.uk/api/west-midlands/BW007/people', 'https://data.police.uk/api/west-midlands/BW008/people', 'https://data.police.uk/api/west-midlands/BW009/people', 'https://data.police.uk/api/west-midlands/BW010/people', 'https://data.police.uk/api/west-midlands/BW011/people', 'https://data.police.uk/api/west-midlands/BW012/people', 'https://data.police.uk/api/west-midlands/BW013/people', 'https://data.police.uk/api/west-midlands/BW014/people', 'https://data.police.uk/api/west-midlands/BW015/people', 'https://data.police.uk/api/west-midlands/BW016/people', 'https://data.police.uk/api/west-midlands/BW017/people', 'https://data.police.uk/api/west-midlands/BW018/people', 'https://data.police.uk/api/west-midlands/BW019/people', 'https://data.police.uk/api/west-midlands/BW020/people', 'https://data.police.uk/api/west-midlands/BW021/people', 'https://data.police.uk/api/west-midlands/BW022/people', 'https://data.police.uk/api/west-midlands/BW023/people', 'https://data.police.uk/api/west-midlands/BW024/people', 'https://data.police.uk/api/west-midlands/BW025/people', 'https://data.police.uk/api/west-midlands/BE011/people', 'https://data.police.uk/api/west-midlands/BE012/people', 'https://data.police.uk/api/west-midlands/BE013/people', 'https://data.police.uk/api/west-midlands/BE014/people', 'https://data.police.uk/api/west-midlands/BE015/people', 'https://data.police.uk/api/west-midlands/BE016/people', 'https://data.police.uk/api/west-midlands/BE017/people', 'https://data.police.uk/api/west-midlands/BE018/people', 'https://data.police.uk/api/west-midlands/BE019/people', 'https://data.police.uk/api/west-midlands/BE020/people', 'https://data.police.uk/api/west-midlands/BW001/people', 'https://data.police.uk/api/west-midlands/BW001/people', 'https://data.police.uk/api/west-midlands/BW002/people', 'https://data.police.uk/api/west-midlands/BW003/people', 'https://data.police.uk/api/west-midlands/BW004/people', 'https://data.police.uk/api/west-midlands/BW00/people5', 'https://data.police.uk/api/west-midlands/BW006/people', 'https://data.police.uk/api/west-midlands/BW007/people', 'https://data.police.uk/api/west-midlands/BW008/people', 'https://data.police.uk/api/west-midlands/BW009/people', 'https://data.police.uk/api/west-midlands/BW010/people', 'https://data.police.uk/api/west-midlands/BW011/people', 'https://data.police.uk/api/west-midlands/BW012/people', 'https://data.police.uk/api/west-midlands/BW013/people', 'https:/ ...

# %%
websites = url_force
contents_list = []

for site in websites:
    website = site
    
    r = requests.get(website)
    contents = json.loads(r.text)
    contents_list.append(contents)
    print (contents_list)
# Out:
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}]]
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}]]
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}]]
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}]]
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}]]
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}]]
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# [[{'bio': None, 'contact_details': {}, 'name': 'Mark Robinson', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Craig Roughton', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'David Jermine', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Ian Ellis', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Innayah Aziz', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Roy Pritchard', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Maninder Taggar', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Martin Clarke', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Daniels', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Susan Haskins', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Louise Maile', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Ellie Smith', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Faye Purcell', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Lee Monk', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Robert Field', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Safayaan Javid', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Meg Skelding', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Neil Collins', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Richard Hodson', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Tracy Baker', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Daniel Donoher', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Matthew Goundry', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Carolyn Oates', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Louise Ruddock', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Richard Edkins', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Roscorla', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Gurpal Singh', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jonathan Harris', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Anne Cunningham', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Julie Meer', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Kelly Day', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Derrington', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Luke Thomas', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Adam Willday', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Jason Roberts', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Carroll', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Corinne Devey', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Giovanni Esposito', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Rebecca Stone', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': "Thomas O'Keeffe", 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Alfred Ratcliffe', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Naiyer Khan', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Thomas Dale', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Zoe Williams', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'Beverley Dickie', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Dawn Moreton', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Fareeda Khan', 'rank': 'PCSO'}, {'bio': None, 'contact_details': {}, 'name': 'Paul Weate', 'rank': 'PCSO'}], [{'bio': None, 'contact_details': {}, 'name': 'Karn Sharma', 'rank': 'Sergeant'}, {'bio': None, 'contact_details': {}, 'name': 'Bethany Ramage', 'rank': 'PC'}, {'bio': None, 'contact_details': {}, 'name': 'John Coates', 'rank': 'PC'}, ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Input In [85], in <cell line: 4>()
#       5 website = site
#       7 r = requests.get(website)
# ----> 8 contents = json.loads(r.text)
#       9 contents_list.append(contents)
#      10 print (contents_list)
#
# File ~\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~\anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df = pd.DataFrame(contents_list)
df
# Out:
#                                                    0   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2   {'bio': None, 'contact_details': {}, 'name': '...
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4   {'bio': None, 'contact_details': {}, 'name': '...
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11  {'bio': None, 'contact_details': {}, 'name': '...
# 12  {'bio': None, 'contact_details': {}, 'name': '...
# 13  {'bio': None, 'contact_details': {}, 'name': '...
# 14  {'bio': None, 'contact_details': {}, 'name': '...
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16  {'bio': None, 'contact_details': {}, 'name': '...
# 17  {'bio': None, 'contact_details': {}, 'name': '...
# 18  {'bio': None, 'contact_details': {}, 'name': '...
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22  {'bio': None, 'contact_details': {}, 'name': '...
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24  {'bio': None, 'contact_details': {}, 'name': '...
# 25  {'bio': None, 'contact_details': {}, 'name': '...
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27  {'bio': None, 'contact_details': {}, 'name': '...
# 28  {'bio': None, 'contact_details': {}, 'name': '...
#
#                                                    1   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2   {'bio': None, 'contact_details': {}, 'name': '...
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4   {'bio': None, 'contact_details': {}, 'name': '...
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11  {'bio': None, 'contact_details': {}, 'name': '...
# 12  {'bio': None, 'contact_details': {}, 'name': '...
# 13  {'bio': None, 'contact_details': {}, 'name': '...
# 14  {'bio': None, 'contact_details': {}, 'name': '...
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16  {'bio': None, 'contact_details': {}, 'name': '...
# 17  {'bio': None, 'contact_details': {}, 'name': '...
# 18  {'bio': None, 'contact_details': {}, 'name': '...
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22  {'bio': None, 'contact_details': {}, 'name': '...
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24  {'bio': None, 'contact_details': {}, 'name': '...
# 25  {'bio': None, 'contact_details': {}, 'name': '...
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27  {'bio': None, 'contact_details': {}, 'name': '...
# 28  {'bio': None, 'contact_details': {}, 'name': '...
#
#                                                    2   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2   {'bio': None, 'contact_details': {}, 'name': '...
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4   {'bio': None, 'contact_details': {}, 'name': '...
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11  {'bio': None, 'contact_details': {}, 'name': '...
# 12  {'bio': None, 'contact_details': {}, 'name': '...
# 13  {'bio': None, 'contact_details': {}, 'name': '...
# 14  {'bio': None, 'contact_details': {}, 'name': '...
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16  {'bio': None, 'contact_details': {}, 'name': '...
# 17  {'bio': None, 'contact_details': {}, 'name': '...
# 18  {'bio': None, 'contact_details': {}, 'name': '...
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22  {'bio': None, 'contact_details': {}, 'name': '...
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24  {'bio': None, 'contact_details': {}, 'name': '...
# 25  {'bio': None, 'contact_details': {}, 'name': '...
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27  {'bio': None, 'contact_details': {}, 'name': '...
# 28  {'bio': None, 'contact_details': {}, 'name': '...
#
#                                                    3   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2   {'bio': None, 'contact_details': {}, 'name': '...
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4   {'bio': None, 'contact_details': {}, 'name': '...
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11  {'bio': None, 'contact_details': {}, 'name': '...
# 12                                               None
# 13  {'bio': None, 'contact_details': {}, 'name': '...
# 14  {'bio': None, 'contact_details': {}, 'name': '...
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16  {'bio': None, 'contact_details': {}, 'name': '...
# 17  {'bio': None, 'contact_details': {}, 'name': '...
# 18  {'bio': None, 'contact_details': {}, 'name': '...
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22  {'bio': None, 'contact_details': {}, 'name': '...
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24  {'bio': None, 'contact_details': {}, 'name': '...
# 25  {'bio': None, 'contact_details': {}, 'name': '...
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27  {'bio': None, 'contact_details': {}, 'name': '...
# 28  {'bio': None, 'contact_details': {}, 'name': '...
#
#                                                    4   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2                                                None
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4   {'bio': None, 'contact_details': {}, 'name': '...
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11  {'bio': None, 'contact_details': {}, 'name': '...
# 12                                               None
# 13                                               None
# 14  {'bio': None, 'contact_details': {}, 'name': '...
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16  {'bio': None, 'contact_details': {}, 'name': '...
# 17  {'bio': None, 'contact_details': {}, 'name': '...
# 18  {'bio': None, 'contact_details': {}, 'name': '...
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22  {'bio': None, 'contact_details': {}, 'name': '...
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24  {'bio': None, 'contact_details': {}, 'name': '...
# 25  {'bio': None, 'contact_details': {}, 'name': '...
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27  {'bio': None, 'contact_details': {}, 'name': '...
# 28  {'bio': None, 'contact_details': {}, 'name': '...
#
#                                                    5   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2                                                None
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4   {'bio': None, 'contact_details': {}, 'name': '...
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11  {'bio': None, 'contact_details': {}, 'name': '...
# 12                                               None
# 13                                               None
# 14  {'bio': None, 'contact_details': {}, 'name': '...
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16  {'bio': None, 'contact_details': {}, 'name': '...
# 17                                               None
# 18                                               None
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24                                               None
# 25  {'bio': None, 'contact_details': {}, 'name': '...
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27                                               None
# 28  {'bio': None, 'contact_details': {}, 'name': '...
#
#                                                    6   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2                                                None
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4   {'bio': None, 'contact_details': {}, 'name': '...
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11  {'bio': None, 'contact_details': {}, 'name': '...
# 12                                               None
# 13                                               None
# 14  {'bio': None, 'contact_details': {}, 'name': '...
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16  {'bio': None, 'contact_details': {}, 'name': '...
# 17                                               None
# 18                                               None
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24                                               None
# 25                                               None
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27                                               None
# 28  {'bio': None, 'contact_details': {}, 'name': '...
#
#                                                    7   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2                                                None
# 3   {'bio': None, 'contact_details': {}, 'name': '...
# 4                                                None
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6   {'bio': None, 'contact_details': {}, 'name': '...
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9   {'bio': None, 'contact_details': {}, 'name': '...
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15  {'bio': None, 'contact_details': {}, 'name': '...
# 16                                               None
# 17                                               None
# 18                                               None
# 19  {'bio': None, 'contact_details': {}, 'name': '...
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23  {'bio': None, 'contact_details': {}, 'name': '...
# 24                                               None
# 25                                               None
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27                                               None
# 28                                               None
#
#                                                    8   \
# 0   {'bio': None, 'contact_details': {}, 'name': '...
# 1   {'bio': None, 'contact_details': {}, 'name': '...
# 2                                                None
# 3                                                None
# 4                                                None
# 5   {'bio': None, 'contact_details': {}, 'name': '...
# 6                                                None
# 7   {'bio': None, 'contact_details': {}, 'name': '...
# 8   {'bio': None, 'contact_details': {}, 'name': '...
# 9                                                None
# 10  {'bio': None, 'contact_details': {}, 'name': '...
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  {'bio': None, 'contact_details': {}, 'name': '...
# 27                                               None
# 28                                               None
#
#                                                    9   ...  \
# 0   {'bio': None, 'contact_details': {}, 'name': '...  ...
# 1   {'bio': None, 'contact_details': {}, 'name': '...  ...
# 2                                                None  ...
# 3                                                None  ...
# 4                                                None  ...
# 5                                                None  ...
# 6                                                None  ...
# 7   {'bio': None, 'contact_details': {}, 'name': '...  ...
# 8   {'bio': None, 'contact_details': {}, 'name': '...  ...
# 9                                                None  ...
# 10                                               None  ...
# 11                                               None  ...
# 12                                               None  ...
# 13                                               None  ...
# 14                                               None  ...
# 15                                               None  ...
# 16                                               None  ...
# 17                                               None  ...
# 18                                               None  ...
# 19                                               None  ...
# 20  {'bio': None, 'contact_details': {}, 'name': '...  ...
# 21  {'bio': None, 'contact_details': {}, 'name': '...  ...
# 22                                               None  ...
# 23                                               None  ...
# 24                                               None  ...
# 25                                               None  ...
# 26                                               None  ...
# 27                                               None  ...
# 28                                               None  ...
#
#                                                    64  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    65  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    66  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    67  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    68  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    69  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    70  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    71  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    72  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
#                                                    73
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  {'bio': None, 'contact_details': {}, 'name': '...
# 21  {'bio': None, 'contact_details': {}, 'name': '...
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
#
# [29 rows x 74 columns]

# %%
df_m1 = pd.json_normalize(contents_list, max_level=1)
df_m1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [96], in <cell line: 1>()
# ----> 1 df_m1 = pd.json_normalize(contents_list, max_level=1)
#       2 df_m1.head()
#
# File ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py:458, in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     455     return DataFrame(_simple_json_normalize(data, sep=sep))
#     457 if record_path is None:
# --> 458     if any([isinstance(x, dict) for x in y.values()] for y in data):
#     459         # naive normalization, this is idempotent for flat records
#     460         # and potentially will inflate the data considerably for
#     461         # deeply nested structures:
#     462         #  {VeryLong: { b: 1,c:2}} -> {VeryLong.b:1 ,VeryLong.c:@}
#     463         #
#     464         # TODO: handle record value which are lists, at least error
#     465         #       reasonably
#     466         data = nested_to_record(data, sep=sep, max_level=max_level)
#     467     return DataFrame(data)
#
# File ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py:458, in <genexpr>(.0)
#     455     return DataFrame(_simple_json_normalize(data, sep=sep))
#     457 if record_path is None:
# --> 458     if any([isinstance(x, dict) for x in y.values()] for y in data):
#     459         # naive normalization, this is idempotent for flat records
#     460         # and potentially will inflate the data considerably for
#     461         # deeply nested structures:
#     462         #  {VeryLong: { b: 1,c:2}} -> {VeryLong.b:1 ,VeryLong.c:@}
#     463         #
#     464         # TODO: handle record value which are lists, at least error
#     465         #       reasonably
#     466         data = nested_to_record(data, sep=sep, max_level=max_level)
#     467     return DataFrame(data)
#
# AttributeError: 'list' object has no attribute 'values'

# %%
data_name = []
data_rank = []
data_details = []

for i in range(len(response_time)):
            try:
                data_category.append(response[i]["name"])
                data["name"] = data_name
            except:    
                data["name"] = ""
            try:
                data_lat.append(response[i][rank])
                data["rank"] = data_rank
            except:
                data["rank"] = ""
            try:
                data_month.append(response_crime[i]["bio"])
                data["bio"] = data_details
            except:
                data["bio"] = ""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 5>()
#       2 data_rank = []
#       3 data_details = []
# ----> 5 for i in range(len(response)):
#       6             try:
#       7                 data_category.append(response[i]["name"])
#
# NameError: name 'response' is not defined

# %%
# normlaize the data to make it clear, however at this part this data didnt work, i will be doing the same put only

#df_m1 = pd.json_normalize(df, max_level=3)
#df_m1.head()

# %%
#Here we change our dictionary into Series, i works on headers, j works on the rest of data rows. 
#Check out documentation for .items function
data_df = pd.DataFrame({i:pd.Series(j) for i, j in data.items()}).

# %%
data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
